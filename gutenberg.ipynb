# %%
# %pip install seaborn
# %pip install pandas
import ipykernel
import pandas as pd
import seaborn as sns
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting numpy!=1.24.0,>=1.20 (from seaborn)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 41.4 MB/s  0:00:006m0:00:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 41.4 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 33.3 MB/s  0:00:00
# Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 50.8 MB/s  0:00:006m0:00:01
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 56.8 MB/s  0:00:00
# Downloading pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 49.6 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib, seaborn
#    ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/10 [numpy]]  WARNING: The scripts f2py and numpy-config are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━  4/10 [fonttools]  WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [seaborn]9/10 [seaborn]ib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 numpy-2.4.2 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2 seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/"
authors = pd.read_csv(f"{url}gutenberg_authors.csv")
languages = pd.read_csv(f"{url}gutenberg_languages.csv")
metadata = pd.read_csv(f"{url}gutenberg_metadata.csv")
metadata.head()
# Out:
#    gutenberg_id                                              title  \
# 0             1  The Declaration of Independence of the United ...
# 1             2  The United States Bill of Rights\r\nThe Ten Or...
# 2             3                John F. Kennedy's Inaugural Address
# 3             4  Lincoln's Gettysburg Address\r\nGiven November...
# 4             5                     The United States Constitution
#
#                                author  gutenberg_author_id language  \
# 0                   Jefferson, Thomas               1638.0       en
# 1                       United States                  1.0       en
# 2  Kennedy, John F. (John Fitzgerald)               1666.0       en
# 3                    Lincoln, Abraham                  3.0       en
# 4                       United States                  1.0       en
#
#                                  gutenberg_bookshelf  \
# 0  Politics/American Revolutionary War/United Sta...
# 1  Politics/American Revolutionary War/United Sta...
# 2    Browsing: History - American/Browsing: Politics
# 3  US Civil War/Browsing: History - American/Brow...
# 4  United States/Politics/American Revolutionary ...
#
#                       rights  has_text
# 0  Public domain in the USA.      True
# 1  Public domain in the USA.      True
# 2  Public domain in the USA.      True
# 3  Public domain in the USA.      True
# 4  Public domain in the USA.      True

# %%
from tt_gutenberg.authors import *
list_authors(by_languages=True, alias=True)
# Out:
# ['Wells, Herbert George',
#  'Chaney, John Griffith',
#  'Jacobs, William Wymark',
#  'Stevenson, R. L. (Robert Louis)',
#  'Ballantyne, Robert Michael',
#  'De Maupassant, Guy',
#  'Lang, Walter Andrew',
#  'Πλάτων',
#  'Wangemann, Eduard Carl Otto',
#  'Barbour, R. H. (Ralph Henry)',
#  "Wilde, Oscar Fingal O'Flahertie Wills",
#  'Sinjohn, John',
#  'Harte, Francis Bret',
#  'Alighieri, Dante',
#  'Ruskin, J. (John)',
#  'Houghton, Carolyn Wells',
#  'Strindberg, Johan August',
#  'Carter, Nick',
#  'Huxley, T. H. (Thomas Henry)',
#  'Gloux, Olivier',
#  'Crawford, Francis Marion',
#  'Collins, William Wilkie',
#  'James, George Payne Rainsford',
#  'Rollan, R.',
#  'Poe, Edgar Allen',
#  'Darwin, Charles Robert',
#  'Chambers, Robert William',
#  'Burgess, Thornton Waldo',
#  'Borrow, George Henry',
#  'Daudet, Louis Marie Alphonse',
#  'Richards, Laura E.',
#  'Snell, Roy Judson',
#  'Michelet, J.',
#  'Yeats, William Butler',
#  'Russell, W. Clark (William Clark)',
#  'Curwood, James-Oliver',
#  'Carlyle, T. (Thomas)',
#  'Swift, J. (Jonathan)',
#  'Becke, George Louis',
#  'Hawkins, Anthony Hope',
#  'Hancock, Harrie Irving',
#  'Crayon, Geoffrey',
#  "O'Hara, Kenneth",
#  'Harper, C. G.',
#  'Όμηρος',
#  'Kataja, Vaino',
#  'Andersen, Hans Christian',
#  'Dodgson, Charles Lutwidge',
#  'Weyman, Stanley J. (Stanley John)',
#  'Wallace, Richard Horatio Edgar',
#  'Lancaster, William Joseph Cosens',
#  'Mikkola, Maila Winter',
#  'Administration, Work Projects',
#  'Brehm, A. E. (Alfred Edmund)',
#  'Gaboriau, Émile',
#  'Allen, Charles Grant Blairfindie',
#  'Holmes, Gordon',
#  'Sabatini, R.',
#  'Sterling, Brett',
#  'Fletcher, Joseph Smith',
#  'Williamson, Charles Norris',
#  'Cobb, Irvin Shrewsbury',
#  'Hall, Eugene Raymond',
#  'Morley, Viscount',
#  'Leiber, Fritz Reuter',
#  "Vandercook, Margaret O'Bannon Womack",
#  'Farjeon, Benjamin Leopold',
#  'Barrili, Antonio Giulio',
#  'Howard, Robert Ervin',
#  'Smith, F. Hopkinson (Francis Hopkinson)',
#  'Wheeler, Ella',
#  'Grile, Dod',
#  'Weymouth, R. F. (Richard Francis)',
#  'C.L.S.C.',
#  'Couperus, Louis Marie Anne',
#  'Jarvis, E. K.',
#  'Morris, William M.',
#  'Guerrazzi, F. D. (Francesco Domenico)',
#  'Stevenson, Burton E.',
#  'Barr, Amelia Edith Huddleston',
#  'Lessing, G. E.',
#  'Raine, William McLeod',
#  'Melville, Hermann',
#  'Coleridge, S. T. (Samuel Taylor)',
#  'Grimm, Jacob Ludwig Carl',
#  'Paivarinta, Pietari',
#  'Blackmore, Richard Doddridge',
#  'Clarke, Rebecca Sophia',
#  'Grimm, Wilhelm Carl',
#  'Fontenay, Charles Louis',
#  'Raymond, Evelyn Hunt',
#  'Marks, Winston Kinney',
#  'Pimentel, Alberto Augusto de Almeida',
#  'Gissing, George Robert',
#  'Stooke, E. H.',
#  'Storm, Hans Theodor Woldsen',
#  'Wilkuna, Kyosti',
#  'Beamont, Francis',
#  'Eotvos, Karoly',
#  'Kock, Charles Paul de',
#  'Mason, Alfred Edward Woodley',
#  'Malot, Hector-Henri',
#  'Korhonen, Veikko Matias',
#  'Roy, Lillian Elizabeth Becker',
#  'Longfellow, Henry W.',
#  'Wassermann, Jacob',
#  'Graham, John',
#  'Porter, William Sidney',
#  'Sinclair, Mary Amelia St. Clair',
#  'Tennyson, Alfred Lord',
#  'Harmon, James Judson',
#  'Herford, O. (Oliver)',
#  'Cantu, Cesare',
#  'Home, Gordon Cochrane',
#  'Douglas, Amanda Minnie',
#  'Griffiths, Arthur George Frederick',
#  'Wade, Mary Hazleton',
#  'Thoreau, Henry D. (Henry David)',
#  'Lie, Jonas Lauritz Idemil',
#  'Burghard, Sidney Groves',
#  'Cawein, Madison J.',
#  'Roberts, Brigham Henry',
#  'Brereton, Frederick Sadleir',
#  'McLaren, Alexander',
#  'Speight, Thomas Wilkinson',
#  'Bunyan, Johann',
#  'United States President (1801-1809)',
#  'Sabin, Edwin Legrand',
#  'Lincoln, Joseph C.',
#  'Merimee, Prosper',
#  'Steel, F. A. (Flora Annie)',
#  'Jefferies, John Richard',
#  'Crockett, Samuel Rutherford',
#  'Walpole, Sir Hugh',
#  'Beach, Rex Ellingwood',
#  'Wuori, M.',
#  'Smith, Johnston',
#  'Mitton, Geraldine Edith',
#  'Hackluyt, Richard',
#  'Snaith, John Collis',
#  'Ambrus, Zoltan',
#  'Roe, E. P. (Edward Payson)',
#  'Disraeli, B. (Benjamin), Earl of Beaconsfield',
#  'Guthrie, Thomas Anstey',
#  'Bacheller, Addison Irving',
#  'Tweedsmuir, John Buchan, Baron',
#  'Glyn, Elinor Sutherland',
#  'Cabell, Branch',
#  'Cellarius',
#  'Erasmus, of Rotterdam',
#  'Aldrich, T. B. (Thomas Bailey)',
#  'Ward, Arthur Sarsfield',
#  'Biro, Lajos',
#  'Hewlett, Maurice Henry',
#  'Morley, Christopher Darlington',
#  'Young, Robert Franklin',
#  'James, Florence Alice Price',
#  'Haeckel, Ernst Heinrich Philipp August',
#  'Mill, J. S. (John Stuart)',
#  'Gull, Cyril Arthur Edward Ranger',
#  'Shelley, P. B. (Percy Bysshe)',
#  'McIntyre, John Thomas',
#  'Reeve, Arthur Benjamin',
#  'Ellis, Henry Havelock',
#  'Sharkey, John Michael',
#  'Leacock, Stephen Butler',
#  'Symonds, J. A. (John Addington)',
#  'Fabian, Warner',
#  'Saunders, Margaret Marshall',
#  'Cory, David Magie',
#  'Hutcheson, John Conroy',
#  'Bang, Herman Joachim',
#  'Woolsey, Sarah Chauncey',
#  'Lonnrot, Elias',
#  'Watson, John',
#  'Boothby, Guy Newell',
#  'Effendi, Shoghi',
#  'Gallun, Raymond Zinke',
#  'Quin, Dan',
#  'Heine, H. (Heinrich)',
#  'Whitman, Walter',
#  'Stoker, Abraham',
#  'Fewkes, J. Walter (Jesse Walter)',
#  'Burgess, Frank Gelett',
#  'Baruch, Moses',
#  'Neville, Kris Ottman',
#  'Ingraham, Colonel Prentiss',
#  'Runeberg, J. L. (Johan Ludvig)',
#  'Browne, Thomas Alexander',
#  'Gordon, Charles William',
#  'Smith, Grace',
#  'Schmitz, James Henry',
#  'Long, William Joseph',
#  'Hasse, Henry Louis',
#  'Zangwill, I. (Israel)',
#  'Paget, Violet',
#  'Parkman, F. (Francis)',
#  'Válmíki',
#  'Kafka, F. (Franz)',
#  'Green, Olive',
#  '羅貫中',
#  'Saintsbury, George Edward Bateman',
#  'Saltus, Edgar Evertson',
#  'Stanhope, Philip Dormer, Earl of Chesterfield',
#  'Forster, Edward Morgan',
#  'Porter, Eleanor Hodgman',
#  'Patchin, Frank Glines',
#  'Siebe, Josefine',
#  'Duellman, William E. (William Edward)',
#  'Smith, Sarah',
#  'Tranquillus, Gaius Suetonius',
#  'Gregg, Hilda Caroline',
#  'March, Anne',
#  'Bazin, Rene',
#  'Abdul-Baha',
#  'Huxley, Aldous Leonard',
#  'Kivinen, Ilmari',
#  'Gribbon, William Lancaster',
#  'Moricz, Zsigmond',
#  'Sydney, Margaret',
#  'Gibbs, George Fort',
#  'Gutenberg, Project',
#  'Banzole, Ottone di',
#  'Coburn, Fordyce, Mrs.',
#  'Luska, Sidney',
#  'Barrett-Browning, Elizabeth',
#  'Deeping, George Warwick',
#  'Steiner, Rudolph',
#  'Bloundelle-Burton, J. (John)',
#  'Harben, William Nathaniel',
#  'Bickerstaff, Isaac',
#  'Engels, Frederick',
#  'Cable, G. W. (George Washington)',
#  'Hegel, G. W. F. (Georg Wilhelm Friedrich)',
#  'Bush, W. (Wilhelm)',
#  'Janvier, Thomas Allibone',
#  'Pyle, Katherine',
#  'Herrick, Robert Welch',
#  'Diderot, Pantophile',
#  'Martin, Violet Florence',
#  'Maspero, Gaston Camille Charles, Sir',
#  'Carey, R. Nouchette (Rosa Nouchette)',
#  'Riis, Jacob August',
#  'Huneker, James Gibbons',
#  'Kelland, Clarence B.',
#  'Serviss, Garrett P. (Garrett Putman)',
#  'Paine, Ralph D. (Ralph Delahaye)',
#  'Tarbell, Ida Minerva',
#  'Hauptmann, Gerhart Johann Robert',
#  'Fitch, Lucy',
#  'Jones, Raymond F. (Raymond Fisher)',
#  'Nodier, Jean Charles Emmanuel',
#  'Mangasarian, Mangasar Mugurditch',
#  'Hurll, Estelle May',
#  'Souvestre, Emile',
#  'Abernathy, Robert Harwood',
#  'Cox, Irving England, Jr.',
#  'Wood, William Charles Henry',
#  'Bullen, Frank T. (Frank Thomas)',
#  'Spence, James Lewis Thomas Chalmers',
#  'Verhaeren, Émile',
#  'Dick, Philip Kindred',
#  'James, G. Wharton (George Wharton)',
#  'Lang, Allen K.',
#  'Goldsmit, Oliver',
#  'Bernard, Paul',
#  'Ohnet, Jorge',
#  'King, William Benjamin Basil',
#  'Mitford, Miss',
#  'Christie, Agatha Mary Clarissa Miller',
#  'Norris, Benjamin Franklin',
#  'Chaucer, Jeffrey',
#  'Cody, Hiram Alfred',
#  'Johnson, Owen McMahon',
#  'Marchmont, Arthur Williams',
#  'Foote, George William',
#  'Glover, Mary Baker',
#  'Bensusan, Samuel Levy',
#  'Verrill, Alpheus Hyatt',
#  "Baha'u'llah",
#  'Sheppard, William Henry Crispin',
#  'Higginson, T. W. (Thomas Wentworth)',
#  'Giacosa, G. (Giuseppe)',
#  'Pemberton, Sir Max',
#  'Conwell, Russell Herman',
#  'Branch, Stephen',
#  'Taylor, M. Imlay (Mary Imlay)',
#  'Freeman, Richard Austin',
#  'Froude, J. A. (James Anthony)',
#  'Kyne, Peter Bernard',
#  'Ewald, Karl',
#  'Beerbohm, Henry Maximilian, Sir',
#  'Hamilton, Frederick William',
#  'Harris, James Thomas',
#  'Stephen, Sir Leslie',
#  'Service, Robert William',
#  'Skinner, Charles Montgomery',
#  'Lindsay, Nicholas Vachel',
#  'Oliver, George',
#  'Burnham, Clara Louise Root',
#  'Jacobi, Carl Richard',
#  'Campbell, Margaretta Wade',
#  'Curtis, W. (William)',
#  'Peck, George Wilbur',
#  'Comstock, Harriet Theresa Smith',
#  'Peltonen, Vihtori',
#  'Holding, Elizabeth Sanxay',
#  'Washington, Booker Taliaferro',
#  'Pennell, J. (Joseph)',
#  'Chambers, R. (Robert)',
#  'Earle, Mary Alice Morse',
#  'Mulford, Clarence E.',
#  'Barnivelt, Esdras',
#  'Zschokke, Johann Heinrich Daniel',
#  'Drake, Samuel A.',
#  'Duer, Alice',
#  'McKimmey, James Earl, Jr.',
#  'Lermina, Jules Hippolyte',
#  'Freitag, Gustav',
#  'Charlton, Elizabeth Emily',
#  'McDowell, Emmett',
#  'Scargill, W. Pitt (William Pitt)',
#  'U.S.A.',
#  'Yorick, Mr.',
#  'Lamb, Mary Ann',
#  'Rette, Adolphe',
#  'Kauppinen, Heikki',
#  'Marshall, Arthur Hammond',
#  'Griffith-Jones, George Chetwynd',
#  'Sheridan, P. H. (Philip Henry)',
#  'Simak, Clifford Donald',
#  'Robertson, Margaret Murray',
#  'Reuter, Heinrich Ludwig Christian Friedrich',
#  'Robinson, Frank Malcolm',
#  'Oxley, James M. (James Macdonald)',
#  'Pennell, E. R. (Elizabeth Robins)',
#  'Marinetti, Filippo Tommaso',
#  'Lafferty, Raphael Aloysius',
#  'Browne, Paul Cameron',
#  'Lea, H. C. (Henry Charles)',
#  'Wilkinson, Elia',
#  'Wheeler, Post, Mrs.',
#  'Smith, Joseph',
#  'Johnson, W. Fletcher (Willis Fletcher)',
#  'Baldwin, Edward',
#  'Austin, Mary Hunter',
#  'Beers, Henry Augustin',
#  'Tyndal, John',
#  'Lehtimaki, Konrad',
#  'Pfeiffer, Ida Reyer',
#  'Frosterus, Teodor Oskar',
#  'Stephens, R. N. (Robert Neilson)',
#  'Blanche, August Teodor',
#  "O'Donnell, Elliot",
#  'Peard, Frances M. (Frances Mary)',
#  'Mabie, Hamilton W. (Hamilton Wright)',
#  'Ray, Fan',
#  'Foulis, Hugh',
#  'Ludwig, Edward William',
#  'Field, Gans T.',
#  'Gilbert, William Schwenck, Sir',
#  'Koskenniemi, V. A. (Veikko Antero)',
#  'Descartes, Rene',
#  'Derry Down Derry',
#  'Cross, Ada Cambridge',
#  'Read, Opie P.',
#  'Rolt-Wheeler, Francis William',
#  'Richardson, John',
#  'Robertson, John Mackinnon',
#  'Peyser, Herbert Francis',
#  'Valding, Victor',
#  'Russell, W. H. (William Howard), Sir',
#  'Cordeaux, J.',
#  'Welby, Horace',
#  'Clifton, Mark Irvin',
#  'Urpia, Jaime Luciano Balmes',
#  'Collumb, Patrick',
#  'Huch, Ricarda Octavia',
#  'Kolb, Anna Mathilde',
#  'Bodenheimer, Maxwell',
#  'Tomlinson, Everett Titsworth',
#  'Teichner, Albert R.',
#  'Charles, Elisabeth Rundle',
#  'Holyoake, G. J. (George Jacob)',
#  'Candolin, Arnold Elias',
#  'Kieviet, C. Joh. (Cornelis Johannes)',
#  'Carman, William Bliss',
#  'Latham, Robert Gordon',
#  'Collins, Archie Frederick',
#  'Gibson, C. D. (Charles Dana)',
#  'Pain, Barry Eric Odell',
#  'Lawson, Henry Archibald Hertzberg',
#  'Karinthy, Friedrich',
#  'Wyman, Levi Parker',
#  'Franck, Harry A.',
#  'Bailey, Irene Temple',
#  '孔子',
#  'Merilainen, Heikki',
#  'Louwerse, P.',
#  'Farrow, George Edward',
#  'Dunkerley, William Arthur',
#  'Macleod, Fiona',
#  'Eliot, Thomas Stearns',
#  "D'Holbach, Baron",
#  'Esse, James',
#  'Leverage, Carl Henry',
#  'Mills, Enos Abijah',
#  '劉向',
#  'Marshall, Emma Martin',
#  'Driscoll, Lieutenant James R.',
#  'Logan, Black Jack',
#  'Della Porta, Giambattista',
#  'Fever, Buck',
#  'Fry, Sheila Kaye-Smith',
#  'Leslie, Miss (Eliza)',
#  'Lamballe, Marie Therese Louise de Savoie-Carignan, princesse de',
#  'Dryfoos, David M.',
#  'Allen, Captain Quincy',
#  'Zuccari, Anna Radius',
#  'Carpenter, Flora Leona',
#  'Wyss, J. D. (Johann David)',
#  'Clouston, Joseph Storer',
#  'Karr, Jean-Alphonse',
#  'Larned, Josephus Nelson',
#  'Schopfer, Jean',
#  'Iron, Ralph',
#  'Davis, W. S. (William Stearns)',
#  'Clarkson, T. (Thomas)',
#  'Bailey, Liberty Hyde',
#  'Stearns, Chas. A.',
#  'Mitchell, J. A. (John Ames)',
#  'Fitzgerald, Francis Scott Key',
#  'Josephus, Titus Flavius',
#  'Janson, Christopher',
#  'Augustine, Saint',
#  'Swan-Manninen, Anni Emilia',
#  'Burtis, Thomas',
#  'Dekker, Eduard Douwes',
#  'Colton, Arthur Willis',
#  'Whistler, C. W. (Charles Watts)',
#  'Upward, A. (Allen)',
#  'Pain, Thomas',
#  'Blake, W. (William)',
#  'Paris, J. A. (John Ayrton)',
#  'Lons, Hermann',
#  'Hart, A. B. (Albert Bushnell)',
#  'Gordon, Samuel Dickey',
#  'Caldecott, R. (Randolph)',
#  'Jordan, D. S. (David Starr)',
#  'Iisalo, Osmo',
#  'Keller, Gotfryd',
#  'Greville, Charles Cavendish Fulke',
#  'Brown, Fred',
#  'Robida, A. (Albert)',
#  'Turner, Alice',
#  'Sardou, V. (Victorien)',
#  'Sohl, Gerald Allan',
#  'Szep, Erno',
#  'Stewart, J. L. (Jane L.)',
#  "M'Carthy, Justin",
#  'Freeman, Lewis Ransome',
#  'Gyulai, Pal',
#  'Figuier, Guillaume-Louis',
#  'Wallace, Lewis',
#  'Schlemihl, Peter',
#  'Key, Ellen Karolina Sofia',
#  'Hume, Martin Andrew Sharp',
#  'Frost, Robert Lee',
#  'Beresford, John Davys',
#  'Pina, Ruy de',
#  'Rocklin, Ross Louis',
#  'Sylvester, Charles H.',
#  'Hanshew, T. W. (Thomas W.)',
#  'Spearman, Frank Hamilton',
#  'Cassels, Walter R.',
#  'Farmer, Philip Jose',
#  'Bain, Francis William',
#  'Von Schmid, Christoph',
#  'Browne, Charles Farrar',
#  'Godwin, Thomas William',
#  'Gould, Nathaniel',
#  '天花藏主人',
#  'Hayha, Johannes',
#  'Knight, Edward Frederick',
#  'Bogue, Lilian Lida Bell',
#  'Dalquest, Walter W. (Walter Woelber)',
#  'Stedman, Jean-Gabriel',
#  'Van Dyne, Edith',
#  'Wilkins, William Henry',
#  'Raleigh, Sir Walter Alexander',
#  'Beard, Mary Caroline',
#  'Beard, Adelia Belle',
#  'Weinbaum, Stanley Grauman',
#  'Ferris, George Titus',
#  'Harding, Arthur Robert',
#  'Valois, Marguerite de',
#  'Keith, Marian',
#  'Ewart, Ernest Andrew',
#  'Graydon, W. Murray (William Murray)',
#  'Mackaye, Percy',
#  'Wheatley, H. B. (Henry Benjamin)',
#  'Stillwell, Laura Jean Libbey',
#  'Finlay, Roger Thompson',
#  'Robespierre, Maximilien Marie Isidore de',
#  'Runa',
#  'Archette, Guy',
#  'Tyerman, Luke',
#  'Finck, Henry Theophilus',
#  'Chatterton, Edward Keble',
#  'Coblentz, Stanton Arthur',
#  'Finberg, Alexander Joseph',
#  'Fillmore, Parker H. (Parker Hoysted)',
#  'Rockwell, Roy',
#  'Rosendal, Magnus',
#  'Harker, Lizzie Allen',
#  'Lefèvre, Edwin',
#  'Lamburn, Richmal Crompton',
#  'McConnell, James Vernon',
#  'Elmendorf, Dwight',
#  '韓嬰',
#  'Brooks, Henry Mason',
#  'Leech, J. (John)',
#  'Society, Pennsylvania Prison',
#  'Howe, Maud',
#  'Slick, Sam',
#  'Sapper, Agnes Brater',
#  'Emerson, Willis G. (Willis George)',
#  'Hopkins, William J.',
#  'Sanborn, Katherine Abbott',
#  'Bunner, Henry Cuyler',
#  'Fraser, W. A. (William Alexander)',
#  'Hill, Carolyn Sherwin Bailey',
#  'Powell, Ardon Van Buren',
#  'Gibson, W. W. (Wilfrid Wilson)',
#  'Congrove, Mr. (William)',
#  'Connolly, James Brendan',
#  'Giacomo, Salvatore di',
#  'Boyesen, Hjalmar H.',
#  'Craig, J. H.',
#  'Vorst, Marie van',
#  'Scully, William Charles',
#  'Talmage, James Edward',
#  'Racine, Jean Baptiste',
#  'Bayly, Ada Ellen',
#  'Passos, John Dos',
#  'Marks, Jeanette Augustus',
#  'Fortescue, John William, Sir',
#  'Parloa, Miss (Maria)',
#  'College, Trinity',
#  'Emlekyl',
#  'Phillips, H. W. (Henry Wallace)',
#  'Talbot, Frederick A.',
#  'Trent, A. G.',
#  'Cherbuliez, Charles Victor',
#  'Davenport, Cyril James Humphries',
#  'Hunt, James Henry Leigh',
#  'Phillipps-Wolley, C.',
#  'Bergman, J. A.',
#  'Dougall, Lily',
#  'Braden, James Andrew',
#  'Caskoden, Edwin',
#  'Inchbald, Elizabeth Simpson',
#  'Orcutt, Wm. Dana (William Dana)',
#  'Walsh, George Ethelbert',
#  'Renard, Pierre Jules',
#  'Bracebridge, Samuel',
#  'Dorsey, J. Owen (James Owen)',
#  'Brod, Maks',
#  'Dalrymple, C. Leona',
#  'McGuire, John Joseph',
#  'Trollope, Frances Eleanor Ternan',
#  'Fennel, Erick',
#  'Drake, Jane Ludlow',
#  'Trumbull, Henry Clay',
#  'Chenevix, Richard',
#  'Danielson, Fannie Hurst',
#  'Ingraham, Joseph Holt',
#  'Broster, Dorothy Kathleen',
#  'Adam, Paul Auguste Marie',
#  'Duncker, Maximilian Wolfgang',
#  'Somerville, Mary Fairfax',
#  'Farrel, Joseph',
#  'Oppenheim, Lassa Francis Lawrence',
#  'Dauthendey\u200f,  Maximilian Albert\u200f',
#  'Whiting, Emily Lillian',
#  'Keller, Helen Adams',
#  'Berkley, George',
#  'Degre, Alajos',
#  'Albertazzi',
#  'Waugh, Alexander Raban',
#  'Amari, M. (Michele)',
#  'West, Wallace George',
#  'Dey, Frederic Van Rensselaer',
#  'Alcott, William Andrus',
#  'Simonds, William',
#  'Henley, W. E. (William Ernest)',
#  'Henham, Ernest G. (Ernest George)',
#  'Jones, Rufus Matthew',
#  'Moore, Frederick F. (Frederick Ferdinand)',
#  'Malthus, Thomas Robert',
#  'Uzanne, Louis Octave',
#  'Hay, John Milton',
#  'Vale, Mark',
#  'Valentine, Douglas',
#  'Vanderem, Fernand',
#  'Wedekind, Benjamin Franklin',
#  'Stead, Robert James Campbell',
#  'Boethius, Anicius Manlius Severinus',
#  'Hedrick, Ulysses Prentiss',
#  'Marcet, Jane Haldimand',
#  'Caffin, Charles Henry',
#  'Quilp, Jocelyn',
#  'Ingram, Eleanor Marie',
#  'Bryce, Viscount',
#  'Stewart, Alfred W. (Alfred Walter)',
#  'Whewell, W. (William)',
#  'Addams, Laura Jane',
#  'Spears, John R.',
#  'Overton, Grant Martin',
#  'Mercer, Cecil William',
#  'Sternheim, William Adolf Carl',
#  'Mackenzie, Donald Alexander',
#  'Dodge, M. E. (Mary Elizabeth)',
#  'Ady, Andrew',
#  'Watts, I. (Isaac)',
#  "Anderson, J. C. O'Gorman, Mrs.",
#  'United States President (1809-1817)',
#  'Merenyi, Laszlo',
#  'Dobson, Henry Austin',
#  'Ahrenberg, Johan Jacob',
#  'Harrison, Mary St. Leger Kingsley',
#  'Punchard, Constance Holme',
#  'Putnam, Geo. Haven',
#  '干寶',
#  'Magnay, Sir William',
#  'Dickinson, Emily Elizabeth',
#  'Verlaine, Paul Marie',
#  'Kahn, Otto Hermann',
#  'Garlanda, Ada',
#  'Rohlfs, Friedrich Gerhard',
#  'Szemere, Gyorgy',
#  'Kivijarvi, Erkki',
#  'Young, Stanley P.',
#  'Swainson, W. (William)',
#  'Leadbeater, Charles Webster',
#  'Clement, Clara Erskine',
#  'Tomlinson, Henry Major',
#  'Gault, William C.',
#  "D'Israeli, I. (Isaac)",
#  'Taylor, B. L. (Bert Leston)',
#  'Lanzi, Luigi Antonio',
#  'Liszt, F. (Franz)',
#  'Gibson, William Hamilton',
#  'Lohrman, Paul',
#  'Finnemore, J. (John)',
#  'Grenfell, Wilfred T.',
#  'Morgan, T. H. (Thomas Hunt)',
#  'Syrett, Janet',
#  'Krehbiel, H. E. (Henry Edward)',
#  'Gallon, T. (Tom)',
#  'Forbes Dennis, Phyllis',
#  'Fredericks, Arnold',
#  'Kilmer, Alfred Joyce',
#  'Conway, M. D. (Moncure Daniel)',
#  'Ball, Robert Stawell, Sir',
#  'Murger, Henry',
#  'Bartlett, F. O. (Frederick Orin)',
#  'Strachey, Giles Lytton',
#  'Crake, Augustine David',
#  'Strong, Harrington',
#  'Leonard, Mary F.',
#  'Coffin, Charles C. (Charles Carleton)',
#  'Tavaststjerna, Karl A. (Karl August)',
#  'Ganghofer, Ludwig Albert',
#  'Rose, John Holland',
#  'Beddington, Ada Esther',
#  'Finch Kelly, Florence',
#  'Linnaeus, Carolus',
#  'Grisar, Hartmannus',
#  'Curtis, Wm. E. (William Eleroy)',
#  'Morgan, Augustus de',
#  'Da Verona, Guido',
#  'Sclater, P. L. (Philip Lutley)',
#  'Gosse, P. H. (Philip Henry)',
#  'Engstrom, Albert',
#  'Sykes, Daniel Frederick Edward',
#  'Bloy, Leon',
#  'Miller, Mary Esther',
#  'Delpit, Marc-Adrien',
#  'Calvin, John',
#  'Colby, Charles William',
#  'Fitch, William Clyde',
#  'Morris, J. E. (Joseph Ernest)',
#  'Hartland, E. Sidney (Edwin Sidney)',
#  'George, W. L.',
#  'Smith, Frank Berkeley',
#  'Eddington, A. S. (Arthur Stanley), Sir',
#  'Ernst, Paul Frederick',
#  'Hastings, Elizabeth',
#  'Bryant, W. C. (William Cullen)',
#  'Wertenbaker, Thomas J.',
#  'Ernst, Otto',
#  'Wilson, T. P.',
#  'Upton, George Putnam',
#  'Becher, Johannes R. (Johannes Robert)',
#  'Campe, J. H. (Joachim Heinrich)',
#  'Bebel, Auguste',
#  'Ericsson, Volter',
#  'Wylie, Ida Alexa Ross',
#  'Erdelyi, Janos',
#  'Blodgett, Levi',
#  'Thwaites, R. G. (Reuben Gold)',
#  'Cameron, V. L. (Verney Lovett)',
#  'Hay, Helen',
#  'Beck, James Montgomery',
#  'Adrien, Georges Hippolyte',
#  'Jeans, Thomas Tendron',
#  'Liljencrantz, Ottilie Adelina',
#  'Quick, John Herbert',
#  'Buonarroti, Michelangelo',
#  'Bupp, Walter',
#  'Dodds, Marcus',
#  'Winter, Nevin Otto',
#  'Lippmann, Julie Mathilde',
#  'Alcock, D.',
#  'New York detective',
#  'Beamish, Richard Joseph',
#  'Bourne, Randolph S.',
#  'Newell, P. S. (Peter S.)',
#  'Verrill Mighels, Philip',
#  'Meyer-Meyrink, Gustav',
#  'Gilson, Charles James Louis',
#  'Metenier, Oscar',
#  'Dilling, L.',
#  'Lang, Jeanie',
#  'Thijsse, Jacobus Pieter',
#  'Burgon, J. W. (John William)',
#  'Bourinot, J. G. (John George)',
#  'Bourke, John G. (John Gregory)',
#  'Thompson, Alexander Hamilton',
#  'Kull, George',
#  'Li, Ya-ko',
#  '谷崎潤一郎',
#  'Hazlitt, W. Carew (William Carew)',
#  'Dennis, Clarence James',
#  'Institute of Home Economics (U.S.). Human Nutrition Research Division',
#  'Korinek, Charles J.',
#  'Mortimer, Mrs. Favell Lee (Bevan)',
#  'Thompson, Silvanus Phillips',
#  'Livius, Titus',
#  'March, Francis Andrew',
#  'Henderson, William James',
#  'Runciman, Walter, Sir',
#  'Young, F. Brett (Francis Brett)',
#  'Pratt, Murray Fletcher',
#  'Jeunesse, Ernest La',
#  'Forbes, Frances Alice Monica',
#  'Irwin, William Henry',
#  'Jerrold, Walter Copeland',
#  'Wong, L. M.',
#  'Bavinck, H. (Herman)',
#  'Marks, Mrs. Lionel',
#  'Baumann, Émile',
#  'Butler, Josephine E.',
#  'Godolphin, Mary',
#  'Hutchinson, Arthur Stuart-Menteth',
#  'Whitney, O. F.',
#  'Ashton, Winifred',
#  'Olmstead, Frederick Law',
#  'Lovik, Karoly',
#  'Cecil, John',
#  'Omond, G. W. T. (George William Thomson)',
#  'Beveridge, Albert Jeremiah',
#  'Szomory, Dezso',
#  'Hamerton, P. G. (Philip Gilbert)',
#  'Galton, Francis, Sir',
#  'Hankins, Arthur P.',
#  'Causey, James Oliver, Jr.',
#  'Benet, Stephen Vincent',
#  'Greinz, Rudolf Heinrich',
#  'Broun, Heywood Campbell',
#  'Weston, Jessie Laidlay',
#  'Farquhar, G. (George)',
#  'Williams, Hugh Noel',
#  'Sherley, George Douglass',
#  'Kloosterman, Jan Ritskes',
#  'Sherman, Francis Joseph',
#  'Remsberg, John Eleazer',
#  'Aquinas, Thomas, Saint',
#  'Lemonnier, Antoine Louis Camille',
#  'Childers, Robert Erskine',
#  'Chenoweth, Alice',
#  'Gubernatis, Angelo de, conte',
#  'Moore, Clement C. (Clement Clarke)',
#  'Willard, J. H. (James Hartwell)',
#  'McFee, William Morley Punshon',
#  'Trollope, T. Adolphus (Thomas Adolphus)',
#  'Гончаров, Иван Александрович',
#  'Brewster, David, Sir',
#  'Sheldon, Charles Monroe',
#  'Cimochowski, Albert Antoine',
#  'Brewer, E. Cobham (Ebenezer Cobham)',
#  'Lyster, Annette M.',
#  'Hull, Edith Maude',
#  'Dudley, Albertus True',
#  'Corbett, Julian Stafford, Sir',
#  'Murray, William Henry Harrison',
#  'Stoddard, C. W. (Charles Warren)',
#  'Murrey, Thomas Jefferson',
#  'Gaebelein, Arno C. (Arno Clemens)',
#  'Church, Richard William',
#  '馮夢龍',
#  'Stillman, W. J. (William James)',
#  'Troward, Thomas',
#  'Faccio, Rina',
#  'Bruce, Henry Addington Bayley',
#  'Brown, Giorgio Rossi',
#  'Lossing, Benson J. (Benson John)',
#  'Brown, Ruth Alberta',
#  'De Fornaro, Carlo',
#  'Bell, Gertrude Margaret Lowthian',
#  'Acton, Lord',
#  'Seward, Albert Charles, Sir',
#  'Achleitner, A. (Arthur)',
#  'Warneford, Lieutenant',
#  'Davis, R. H. (Rebecca Harding)',
#  'Kobbe, Gustav',
#  'Smith, Harriet Lummis',
#  'White, W. A. (William Allen)',
#  'Kobor, Tamas',
#  'Northend, Mary H.',
#  'Gratacap, Louis Pope',
#  'Schoepflin, Harold Vincent',
#  'Howard, John Hayden',
#  'Street, Julian Leonard',
#  'Neihardt, John Gneisenau',
#  'Planck, Max Karl Ernst Ludwig',
#  'Macaulay, Fannie Caldwell',
#  'Mahaffy, John Pentland',
#  'Cutting, Mary Stewart Doubleday',
#  'Morley, Margaret W.',
#  'Jacobsen, Jens Peter',
#  'Meek, Sterner St. Paul',
#  'Carington, Hereward',
#  'Houssaye, Arsene',
#  'Blaikie, W. G. (William Garden)',
#  'Wilson, Daniel',
#  'Hooker, J. D. (Joseph Dalton)',
#  'Hollingworth, Leta S.',
#  'Edison, Thomas Alva',
#  'French, Alice',
#  'Donquichote, Marguerite',
#  'Theilhaber-Berlin, Felix A.',
#  'Edwardes, Edward Tickner',
#  'Say, T. (Thomas)',
#  'Edwards, O. M., Sir',
#  'Corroyer, Édouard',
#  'Corson, Miss (Juliet)',
#  'Soyer, A. (Alexis)',
#  'Smith, G. Elliot (Grafton Elliot), Sir',
#  'Franklin, John, Sir',
#  'Swinnerton, Frank Arthur',
#  'Tegner, Esaias',
#  'Sallustius Crispus, Gaius',
#  'Doff, Cornelia Hubertina',
#  'Howard-Smith, Logan',
#  'Platz, Josephine Lawrence',
#  'Buchan, Anna',
#  'Sainsbury, Noel Everingham',
#  'Cox, S. A. D.',
#  'Cooke, Joan Conquest',
#  'Craine, Edith Janice',
#  'Doede, Bill',
#  'Holland, William Jacob',
#  'Garratt, Evelyn Rosalie',
#  'Hoar, Roger Sherman',
#  'Durand, Lucinda',
#  'Gasson, Herbert N. (Herbert Newton)',
#  'Dodge, Natt Noyes',
#  'Thayer, William M. (William Makepeace)',
#  'Pritchett, Robert Taylor',
#  'Savage, Richard Henry',
#  'Duff, Edward Gordon',
#  'Frapie, Leon',
#  'Bromfield, Luis',
#  'Wald, E. G. von',
#  'Hobson, John Atkinson',
#  'Cavallotti, Felice Carlo Emanuele',
#  'Rochester, Faunce',
#  'Torrey, Reuben Archer',
#  'Hamp, Sidford Frederick',
#  'Clarke, Helen Archibald',
#  'Clarke, J. F. (James Freeman)',
#  'Hankinson, Charles James',
#  'Reinsberg, Mark Simon',
#  'Stredder, E.\u200f (Eleanor)\u200f',
#  'Faraday, M. (Michael)',
#  'Clarke, W. Eagle',
#  'Greenaway, K. (Kate)',
#  'Flindt, Homer Eon',
#  'Falkner, J. Meade (John Meade)',
#  'Hardy, Godfrey Harold',
#  'Hare, Augustus John Cuthbert',
#  'Carson, Captain James',
#  'Shiel, Matthew Phipps',
#  'Harkonen, Iivo',
#  'Rodenbach, Georges (Georges-Raymond-Constantin)',
#  'Reed, Earl Howell',
#  'Reed, Chester Albert',
#  'Fabré, Lucien',
#  'United States President (1789-1797)',
#  'Clerke, Agnes Mary',
#  'Sherman, Frank James',
#  'Cheyney, E. G. (Edward Gheen)',
#  'Fichte, J. G. (Johann Gottlieb)',
#  'Shackleton, E. H. (Ernest Henry), Sir',
#  'Tregarthen, John Coulson',
#  'Ferri, Enrique',
#  'Gruelle, John B. (John Barton)',
#  'Rimbaud, Jean Nicolas Arthur',
#  'Field, Henry Martyn',
#  'Sheard, Virginia Stanton',
#  'Traill, Henry Duff',
#  'Findley, James Smith',
#  'Dana, R. H. (Richard Henry)',
#  'Clark, Ellery Harding',
#  'Haggard, John Harvey',
#  'Hague, William Grant',
#  'Hahl, J.',
#  'Tucker, Thomas George',
#  'Chapelle, Howard I. (Howard Irving)',
#  'Robertson, Morgan Andrew',
#  'Faure, Georges Le',
#  'Griggs, Sutton Elbert',
#  'Hall, Florence Marion (Howe)',
#  'Hall, Gertrude',
#  'Richards, Frederick Charles',
#  'Sewell, Ana',
#  'Robinson, William',
#  'Stoddard, John Lawson',
#  'Rakosi, Viktor',
#  'Heer, Jakob Christoph',
#  'Denslow, William Wallace',
#  'Vandenberg, G. L.',
#  'Rahkonen, A.',
#  'Engel, Georg Julius Leopold',
#  'Ford, Ricardo',
#  'Hellaakoski, Aaro Antti',
#  'Crooke, W.',
#  'Hemmer, Jarl Robert',
#  'Hemon, Louis',
#  'Scott, D. C. (Duncan Campbell)',
#  'Firbank, Arthur Annesley Ronald',
#  'Busk, R. H. (Rachel Harriette)',
#  'Collins, William Wiehe',
#  'Ely, Wilmer Mateo',
#  'Busch, Julius Hermann Moritz',
#  'Herbert, Franklin Patrick, Jr.',
#  'Russell, Robert Vane',
#  'Scollard, Clifton',
#  'Thomas, Theodore Lockard',
#  'Thomas, Michael Rogers Oldfield',
#  'Fox, G. (George)',
#  'Burke, Sydney Thomas',
#  'Cram, R. A. (Ralph Adams)',
#  'Collins, William Lucas',
#  'Carpenter, Frank George',
#  'Sevilla, José N.',
#  'Curtis, Thomas Day',
#  'Evans, Edward Everett',
#  'Stephens, John Lloyd',
#  'Fiske, Colonel James',
#  'De Wit, Augusta',
#  'United States President (1897-1901)',
#  'Sten, Daniel',
#  'Graham, D. (Dougal)',
#  'Grabau, Mary Antin',
#  'Steiner, Edward A.',
#  'Summers, Charlie',
#  'Hastings, Mary Bradley',
#  'Erkko, Juhana Heikki',
#  'Goulart, Ronald Joseph',
#  'Valery, Paul',
#  'Gore, C. (Charles)',
#  'Flebbe, Beulah Dix',
#  'Haywood, Mrs. (Eliza Fowler)',
#  'Ramsay, Anders Gustaf',
#  'English, Society for Pure',
#  'English, Geo. Bethune (George Bethune)',
#  'Rowsell, Mary Catherine',
#  'Floyd, Silas X.',
#  'Cruickshank, George',
#  'Gozlan, Leon',
#  'Barber, Margaret Fairless',
#  'Moersberger, Rose Felicitas',
#  'Beddard, Frank Evers',
#  'Kotka, Pietari',
#  'Nitsch, Helen Alice Matthews',
#  'Montalte, Louis de',
#  'Arcot, Roger',
#  ...]
